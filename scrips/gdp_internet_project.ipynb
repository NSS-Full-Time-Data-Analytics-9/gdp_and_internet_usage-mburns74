# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %% [markdown]
# ## Question 5

# %%
gdp_df.shape
# Out:
# (7176, 4)

# %% [markdown]
# Above checked number of rows and columns

# %% [markdown]
# There are 7176 rows and 4 columns

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# Country or Area is object, Year is int64, Value is float64, Value Footnote = float64

# %% [markdown]
# ## Question 6

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %% [markdown]
# Above removed column 'value footnotes'. Had to save gdp_df (gdp_df=) to get the column to go away

# %%
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %%
gdp_df.columns = ['Country','Year','GDP_Per_Capita']

# %% [markdown]
# Above changed names of columns

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# ## Question 7

# %%
country_count = gdp_df.Country.value_counts()

# %% [markdown]
# Above counted each countries years, Created a series called 'country_count'

# %%
country_count
# Out:
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# Kosovo                                          13
# Turks and Caicos Islands                        10
# Sint Maarten (Dutch part)                       10
# Somalia                                          8
# Djibouti                                         8
# Name: Country, Length: 242, dtype: int64

# %%
type(country_count)
# Out:
# pandas.core.series.Series

# %% [markdown]
# checked country_count data type

# %%
country_count = country_count.to_frame()

# %% [markdown]
# Above changed country_count from series to dataframe

# %%
type(country_count)
# Out:
# pandas.core.frame.DataFrame

# %%
country_count = country_count.reset_index()

# %%
country_count
# Out:
#                                             index  Country
# 0    Least developed countries: UN classification       31
# 1                                           Niger       31
# 2         Middle East & North Africa (IDA & IBRD)       31
# 3                                   Middle income       31
# 4                                        Mongolia       31
# ..                                            ...      ...
# 237                                        Kosovo       13
# 238                      Turks and Caicos Islands       10
# 239                     Sint Maarten (Dutch part)       10
# 240                                       Somalia        8
# 241                                      Djibouti        8
#
# [242 rows x 2 columns]

# %%
country_count.head(206)
# Out:
#                                             index  Country
# 0    Least developed countries: UN classification       31
# 1                                           Niger       31
# 2         Middle East & North Africa (IDA & IBRD)       31
# 3                                   Middle income       31
# 4                                        Mongolia       31
# ..                                            ...      ...
# 201      Fragile and conflict affected situations       31
# 202                                       Ireland       31
# 203                                        France       31
# 204                                         Italy       31
# 205                                  Turkmenistan       30
#
# [206 rows x 2 columns]

# %% [markdown]
# Above indexed country_count

# %% [markdown]
# 205 countries have data for all years

# %%
country_count.tail()
# Out:
#                          index  Country
# 237                     Kosovo       13
# 238   Turks and Caicos Islands       10
# 239  Sint Maarten (Dutch part)       10
# 240                    Somalia        8
# 241                   Djibouti        8

# %% [markdown]
# Dijbouti and Somalia are missing the most years of data. Both are in Africa

# %%
gdp_2020 = gdp_df.loc[(gdp_df.Year == 2020)]

# %%
gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
plt.hist(gdp_2020.GDP_Per_Capita)
# Out:
# (array([110.,  60.,  23.,  20.,  14.,   6.,   3.,   1.,   2.,   1.]),
#  array([   731.06407364,  11913.68861346,  23096.31315328,  34278.9376931 ,
#          45461.56223291,  56644.18677273,  67826.81131255,  79009.43585237,
#          90192.06039218, 101374.684932  , 112557.30947182]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 2020 Histogram

# %%
sns.kdeplot(gdp_2020.GDP_Per_Capita)
# Out:
# <AxesSubplot:xlabel='GDP_Per_Capita', ylabel='Density'>

# %% [markdown]
# 2020 Density Plot

# %%
plt.boxplot(gdp_2020.GDP_Per_Capita)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cf38a374f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cf38a37a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cf38a37220>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cf38a46070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cf38a46340>],
#  'means': []}

# %%
plt.violinplot(gdp_2020.GDP_Per_Capita)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1cf38ad8490>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1cf38ad8400>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1cf38ad8b50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1cf38ad8f10>}

# %% [markdown]
# Violin Plot

# %% [markdown]
# Most countries GDP is around 5000. The BoxPlot doesnt show this very well

# %%
np.median([gdp_2020.GDP_Per_Capita])
# Out:
# 12908.9374056206

# %% [markdown]
# Median for 2020 is 12908.93 or 12909

# %%
gdp_decades = gdp_df.loc[(gdp_df.Year == 1990)|(gdp_df.Year == 2000)|(gdp_df.Year == 2010)|(gdp_df.Year == 2020)]

# %% [markdown]
# Instructions say subset but really need mask. Can pass multiple criteria in mask by using "|" which is Shift + Key Above Enter

# %% [markdown]
# ## Question 9

# %%
gdp_decades
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 10                    Afghanistan  2010     1957.029070
# 19    Africa Eastern and Southern  2020     3491.978104
# 29    Africa Eastern and Southern  2010     3545.205203
# 39    Africa Eastern and Southern  2000     2915.472987
# ...                           ...   ...             ...
# 7144                       Zambia  1990     2190.181724
# 7145                     Zimbabwe  2020     2134.555461
# 7155                     Zimbabwe  2010     1813.531764
# 7165                     Zimbabwe  2000     2771.060576
# 7175                     Zimbabwe  1990     2652.129209
#
# [918 rows x 3 columns]

# %% [markdown]
# ## Question 10 - Graph Practice

# %%
plt.boxplot(gdp_decades.GDP_Per_Capita)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cf38b5f070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cf38b5f610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cf38b4dd60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cf38b5fbe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cf38b5feb0>],
#  'means': []}

# %% [markdown]
# Need to see more examples of these types of graphs from Chris

# %%
plt.bar( x = 'Year', height = 'GDP_Per_Capita', data = gdp_decades)
# Out:
# <BarContainer object of 918 artists>

# %% [markdown]
# Need to see more examples of these types of graphs from Chris

# %%
plt.scatter( x = 'Year', y = 'GDP_Per_Capita', data = gdp_decades)

# %% [markdown]
# Need To Add Scatter With TrendLine Here -

# %% [markdown]
# ## Question - 11

# %%
gdp_less_than_100k = gdp_df.loc[(gdp_df.GDP_Per_Capita > 100000)]

# %%
gdp_less_than_100k.sort_values(by = 'Year', ascending = True )
# Out:
#                    Country  Year  GDP_Per_Capita
# 6838  United Arab Emirates  1990   111454.055665
# 6837  United Arab Emirates  1991   106103.552655
# 6836  United Arab Emirates  1992   103470.924576
# 6834  United Arab Emirates  1994   100213.156226
# 6833  United Arab Emirates  1995   101570.992100
# 6832  United Arab Emirates  1996   102211.638844
# 6831  United Arab Emirates  1997   105108.996265
# 6830  United Arab Emirates  1998   100100.435658
# 6828  United Arab Emirates  2000   102494.714624
# 3901            Luxembourg  2001   101143.147977
# 3900            Luxembourg  2002   103317.331098
# 3899            Luxembourg  2003   104743.000088
# 3898            Luxembourg  2004   107634.837198
# 3897            Luxembourg  2005   108632.360016
# 3896            Luxembourg  2006   113346.035782
# 3895            Luxembourg  2007   120647.822959
# 3894            Luxembourg  2008   118154.667184
# 3893            Luxembourg  2009   112230.081410
# ...

# %% [markdown]
# United Arab Emirates reached 100k in 1990

# %% [markdown]
# ## Question 12

# %%
gdp_2020.sort_values(by = 'GDP_Per_Capita', ascending = False)
# Out:
#                        Country  Year  GDP_Per_Capita
# 3882                Luxembourg  2020   112557.309472
# 5720                 Singapore  2020    94505.636160
# 3071                   Ireland  2020    90789.221024
# 5381                     Qatar  2020    85290.450430
# 639                    Bermuda  2020    76105.138057
# ...                        ...   ...             ...
# 4750                     Niger  2020     1221.269930
# 5871                   Somalia  2020     1180.965971
# 1524           Dem. Rep. Congo  2020     1082.445242
# 1136  Central African Republic  2020      937.856470
# 914                    Burundi  2020      731.064074
#
# [240 rows x 3 columns]

# %% [markdown]
# Luxembourg

# %% [markdown]
# ## Create Luxembourg Plot Over Time

# %%
gdp_luxembourg = gdp_df.loc[(gdp_df.Country == 'Luxembourg')]

# %%
gdp_luxembourg
# Out:
#          Country  Year  GDP_Per_Capita
# 3882  Luxembourg  2020   112557.309472
# 3883  Luxembourg  2019   116518.276815
# 3884  Luxembourg  2018   115049.926079
# 3885  Luxembourg  2017   114985.842236
# 3886  Luxembourg  2016   116283.699681
# 3887  Luxembourg  2015   113182.728563
# 3888  Luxembourg  2014   113313.578898
# 3889  Luxembourg  2013   113050.663254
# 3890  Luxembourg  2012   112137.135491
# 3891  Luxembourg  2011   112998.390477
# 3892  Luxembourg  2010   114343.988089
# 3893  Luxembourg  2009   112230.081410
# 3894  Luxembourg  2008   118154.667184
# 3895  Luxembourg  2007   120647.822959
# 3896  Luxembourg  2006   113346.035782
# 3897  Luxembourg  2005   108632.360016
# 3898  Luxembourg  2004   107634.837198
# 3899  Luxembourg  2003   104743.000088
# 3900  Luxembourg  2002   103317.331098
# 3901  Luxembourg  2001   101143.147977
# 3902  Luxembourg  2000    99301.526999
# 3903  Luxembourg  1999    94115.384035
# 3904  Luxembourg  1998    88185.800110
# ...

# %%
plt.scatter(x = 'Year', y ='GDP_Per_Capita', data = gdp_luxembourg)

# %% [markdown]
# ## Question 13

# %%
gdp_2020.sort_values(by = 'GDP_Per_Capita', ascending = True)
# Out:
#                        Country  Year  GDP_Per_Capita
# 914                    Burundi  2020      731.064074
# 1136  Central African Republic  2020      937.856470
# 1524           Dem. Rep. Congo  2020     1082.445242
# 5871                   Somalia  2020     1180.965971
# 4750                     Niger  2020     1221.269930
# ...                        ...   ...             ...
# 639                    Bermuda  2020    76105.138057
# 5381                     Qatar  2020    85290.450430
# 3071                   Ireland  2020    90789.221024
# 5720                 Singapore  2020    94505.636160
# 3882                Luxembourg  2020   112557.309472
#
# [240 rows x 3 columns]

# %% [markdown]
# Burundi had the lowest GDP in 2020

# %% [markdown]
# ## Create Luxembourg Plot Over Time

# %%
gdp_burundi = gdp_df.loc[(gdp_df.Country == 'Burundi')]

# %%
gdp_burundi
# Out:
#      Country  Year  GDP_Per_Capita
# 914  Burundi  2020      731.064074
# 915  Burundi  2019      751.443405
# 916  Burundi  2018      761.524143
# 917  Burundi  2017      773.572859
# 918  Burundi  2016      794.604340
# 919  Burundi  2015      825.205574
# 920  Burundi  2014      886.235296
# 921  Burundi  2013      877.272857
# 922  Burundi  2012      862.715651
# 923  Burundi  2011      852.502576
# 924  Burundi  2010      846.169112
# 925  Burundi  2009      831.564843
# 926  Burundi  2008      827.792334
# 927  Burundi  2007      815.908213
# 928  Burundi  2006      815.053647
# 929  Burundi  2005      798.704845
# 930  Burundi  2004      817.461177
# 931  Burundi  2003      804.884232
# 932  Burundi  2002      839.777920
# 933  Burundi  2001      826.028960
# 934  Burundi  2000      828.000479
# 935  Burundi  1999      850.046951
# 936  Burundi  1998      870.043821
# 937  Burundi  1997      839.196865
# 938  Burundi  1996      861.482899
# 939  Burundi  1995      947.822231
# ...

# %%
plt.scatter(x = 'Year', y ='GDP_Per_Capita', data = gdp_burundi)

# %% [markdown]
# ## Question 14

# %%
internet_df = pd.read_csv('../data/internet_use.csv',on_bad_lines = 'skip')

# %%
internet_df
# Out:
#      Country or Area                                               Year  \
# 0        Afghanistan                                               2014
# 1        Afghanistan                                               2013
# 2        Afghanistan                                               2012
# 3        Afghanistan                                               2011
# 4        Afghanistan                                               2010
# ...              ...                                                ...
# 4670             175             Includes individuals 3 years and older
# 4671             176                                   NTIA/CPS survey.
# 4672             178  Estimated based on Survey's results. Populatio...
# 4673             179                     Preliminary. Country estimate.
# 4674             180  The methodology used to estimated the figure f...
#
#          Value  Value Footnotes
# 0     6.390000              NaN
# 1     5.900000              NaN
# ...

# %%
internet_df.head()
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN

# %%
internet_df.tail()
# Out:
#      Country or Area                                               Year  \
# 4670             175             Includes individuals 3 years and older
# 4671             176                                   NTIA/CPS survey.
# 4672             178  Estimated based on Survey's results. Populatio...
# 4673             179                     Preliminary. Country estimate.
# 4674             180  The methodology used to estimated the figure f...
#
#       Value  Value Footnotes
# 4670    NaN              NaN
# 4671    NaN              NaN
# 4672    NaN              NaN
# 4673    NaN              NaN
# 4674    NaN              NaN

# %% [markdown]
# ## Question 15

# %%
internet_df = internet_df.drop(columns =['Value Footnotes'])

# %%
internet_df
# Out:
#      Country or Area                                               Year  \
# 0        Afghanistan                                               2014
# 1        Afghanistan                                               2013
# 2        Afghanistan                                               2012
# 3        Afghanistan                                               2011
# 4        Afghanistan                                               2010
# ...              ...                                                ...
# 4670             175             Includes individuals 3 years and older
# 4671             176                                   NTIA/CPS survey.
# 4672             178  Estimated based on Survey's results. Populatio...
# 4673             179                     Preliminary. Country estimate.
# 4674             180  The methodology used to estimated the figure f...
#
#          Value
# 0     6.390000
# 1     5.900000
# 2     5.454545
# 3     5.000000
# 4     4.000000
# ...

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']

# %%
internet_df
# Out:
#           Country                                               Year  \
# 0     Afghanistan                                               2014
# 1     Afghanistan                                               2013
# 2     Afghanistan                                               2012
# 3     Afghanistan                                               2011
# 4     Afghanistan                                               2010
# ...           ...                                                ...
# 4670          175             Includes individuals 3 years and older
# 4671          176                                   NTIA/CPS survey.
# 4672          178  Estimated based on Survey's results. Populatio...
# 4673          179                     Preliminary. Country estimate.
# 4674          180  The methodology used to estimated the figure f...
#
#       Internet_Users_Pct
# 0               6.390000
# 1               5.900000
# 2               5.454545
# 3               5.000000
# ...

# %% [markdown]
# ## Question 16

# %% [markdown]
# Notice the bottom porition of the data set includes notes

# %% [markdown]
# ## Attempting to clean foot notes from data set

# %% [markdown]
# internet_df = internet_df[(internet_df.Year > '1959') | (internet_df.Year < '2015')]

# %% [markdown]
# ## Question 17

# %%
internet_above_0 = internet_df.loc[(internet_df.Internet_Users_Pct > 0)]

# %%
internet_above_0
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4489     Zimbabwe  1998            0.081648
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
#
# [4106 rows x 3 columns]

# %%
internet_above_0.sort_values(by = 'Internet_Users_Pct', ascending = True )
# Out:
#                                  Country  Year  Internet_Users_Pct
# 1318                            Ethiopia  1995            0.000018
# 3999                            Thailand  1991            0.000052
# 1016                                Cuba  1995            0.000092
# 927   Congo (Democratic Republic of the)  1996            0.000108
# 1913                               India  1992            0.000111
# ...                                  ...   ...                 ...
# 1868                             Iceland  2012           96.209800
# 3016                              Norway  2014           96.300000
# 1867                             Iceland  2013           96.546800
# 415                              Bermuda  2014           96.800000
# 1866                             Iceland  2014           98.160000
#
# [4106 rows x 3 columns]

# %% [markdown]
# 1995 at.000018

# %% [markdown]
# ## Question 18

# %%
internet_df_00_14 = internet_df.loc[(internet_df.Year == '2014')|(internet_df.Year == '2000')]

# %%
internet_df_00_14.sort_values(by = 'Year', ascending = True)
# Out:
#                           Country  Year  Internet_Users_Pct
# 2255                   Kyrgyzstan  2000            1.041401
# 2291                       Latvia  2000            6.319062
# 2311                      Lebanon  2000            7.952744
# 2332                      Lesotho  2000            0.211806
# 2350                      Liberia  2000            0.017703
# ...                           ...   ...                 ...
# 2687  Micronesia (Fed. States of)  2014           29.650000
# 2707                      Moldova  2014           46.600000
# 848                      Colombia  2014           52.570000
# 2745                     Mongolia  2014           27.000000
# 0                     Afghanistan  2014            6.390000
#
# [401 rows x 3 columns]

# %% [markdown]
# ## Bar Chart to compare differences between 2000 & 2014

# %%
plt.bar(x = 'Year', height ='Internet_Users_Pct', data = internet_df_00_14)
# Out:
# <BarContainer object of 401 artists>

# %% [markdown]
# Distrubtion More Than Doubled from 2000 to 2014

# %% [markdown]
# ## Question 19

# %%
below_5_percent = internet_df.loc[(internet_df.Year == '2014')]

# %%
below_5_percent.loc[(below_5_percent.Internet_Users_Pct < 5.0)]
# Out:
#                                  Country  Year  Internet_Users_Pct
# 623                              Burundi  2014                1.38
# 762                 Central African Rep.  2014                4.03
# 782                                 Chad  2014                2.50
# 909   Congo (Democratic Republic of the)  2014                3.00
# 1065         Dem. People's Rep. of Korea  2014                0.00
# 1256                             Eritrea  2014                0.99
# 1299                            Ethiopia  2014                2.90
# 1720                              Guinea  2014                1.72
# 1742                       Guinea-Bissau  2014                3.32
# 2453                          Madagascar  2014                3.70
# 2814                             Myanmar  2014                2.10
# 2975                               Niger  2014                1.95
# 3533                        Sierra Leone  2014                2.10
# ...

# %% [markdown]
# 16 Countries Under 5% in 2014

# %% [markdown]
# ## Question 20 - Merge two dataframes

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df,
                               left_on = 'Country', right_on ='Country',
                               how = 'outer')

# %%
gdp_and_internet_use
# Out:
#             Country  Year_x  GDP_Per_Capita  \
# 0       Afghanistan  2020.0     1970.560169
# 1       Afghanistan  2020.0     1970.560169
# 2       Afghanistan  2020.0     1970.560169
# 3       Afghanistan  2020.0     1970.560169
# 4       Afghanistan  2020.0     1970.560169
# ...             ...     ...             ...
# 111799          175     NaN             NaN
# 111800          176     NaN             NaN
# 111801          178     NaN             NaN
# 111802          179     NaN             NaN
# 111803          180     NaN             NaN
#
#                                                    Year_y  Internet_Users_Pct
# 0                                                    2014            6.390000
# 1                                                    2013            5.900000
# 2                                                    2012            5.454545
# 3                                                    2011            5.000000
# ...

# %% [markdown]
# ## Question 21

# %%
gdp_inter_2014 = gdp_and_internet_use.loc[(gdp_and_internet_use.Year_y == '2014')]

# %%
gdp_inter_2014.sort_values(by = 'Internet_Users_Pct', ascending = False).head(60)
# Out:
#        Country  Year_x  GDP_Per_Capita Year_y  Internet_Users_Pct
# 45457  Iceland  1998.0    39017.437682   2014               98.16
# 45232  Iceland  2007.0    52827.010123   2014               98.16
# 44957  Iceland  2018.0    56818.195837   2014               98.16
# 44982  Iceland  2017.0    55638.492059   2014               98.16
# 45007  Iceland  2016.0    54665.763916   2014               98.16
# 45032  Iceland  2015.0    52142.932807   2014               98.16
# 45057  Iceland  2014.0    50450.741612   2014               98.16
# 45082  Iceland  2013.0    50168.688535   2014               98.16
# 45107  Iceland  2012.0    48440.255084   2014               98.16
# 45157  Iceland  2010.0    47457.622919   2014               98.16
# 45182  Iceland  2009.0    48770.950337   2014               98.16
# 45207  Iceland  2008.0    52999.437536   2014               98.16
# 45257  Iceland  2006.0    49956.848645   2014               98.16
# ...

# %% [markdown]
# Iceland, Bermuda, Norway

# %%
top_3 = gdp_and_internet_use.loc[(gdp_and_internet_use.Country == 'Iceland')|(gdp_and_internet_use.Country == 'Bermuda')|(gdp_and_internet_use.Country == 'Norway')]

# %%
top_3
# Out:
#        Country  Year_x  GDP_Per_Capita Year_y  Internet_Users_Pct
# 11507  Bermuda  2020.0    76105.138057   2014           96.800000
# 11508  Bermuda  2020.0    76105.138057   2013           95.300000
# 11509  Bermuda  2020.0    76105.138057   2012           91.299305
# 11510  Bermuda  2020.0    76105.138057   2011           88.336000
# 11511  Bermuda  2020.0    76105.138057   2010           84.210000
# ...        ...     ...             ...    ...                 ...
# 74654   Norway  1990.0    42136.603168   1994            4.152450
# 74655   Norway  1990.0    42136.603168   1993            2.783991
# 74656   Norway  1990.0    42136.603168   1992            2.216366
# 74657   Norway  1990.0    42136.603168   1991            1.407395
# 74658   Norway  1990.0    42136.603168   1990            0.707299
#
# [2076 rows x 5 columns]

# %%
sns.FacetGrid(top_3, col = 'Year_x', hue = 'Country' )

# %% [markdown]
# ## Question 22

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use.loc[(gdp_and_internet_use.Year_x == '2014.0')|(gdp_and_internet_use.Year_y == "2014")]

# %%
gdp_and_internet_use_2014
# Out:
#                       Country  Year_x  GDP_Per_Capita Year_y  \
# 0                 Afghanistan  2020.0     1970.560169   2014
# 15                Afghanistan  2019.0     2065.036235   2014
# 30                Afghanistan  2018.0     2033.804389   2014
# 45                Afghanistan  2017.0     2058.400221   2014
# 60                Afghanistan  2016.0     2057.067978   2014
# ...                       ...     ...             ...    ...
# 111515                 Turkey     NaN             NaN   2014
# 111538              Venezuela     NaN             NaN   2014
# 111562               Viet Nam     NaN             NaN   2014
# 111582  Virgin Islands (U.S.)     NaN             NaN   2014
# 111604                  Yemen     NaN             NaN   2014
#
#         Internet_Users_Pct
# 0                     6.39
# 15                    6.39
# 30                    6.39
# 45                    6.39
# 60                    6.39
# ...                    ...
# 111515               51.04
# ...
